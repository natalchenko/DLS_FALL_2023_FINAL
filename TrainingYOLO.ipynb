# %%
# !pip install ultralytics

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=model_config.yaml epochs=50
# Out:
# Ultralytics YOLOv8.1.3 рџљЂ Python-3.11.5 torch-2.1.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
#   0%|          | 0.00/755k [00:00<?, ?B/s]
#  20%|##        | 152k/755k [00:00<00:00, 1.51MB/s]
#  79%|#######9  | 600k/755k [00:00<00:00, 3.30MB/s]
# 100%|##########| 755k/755k [00:00<00:00, 3.53MB/s]
#
# train: Scanning C:\Users\alexa\PycharmProjects\CondaYOLO\datasets\labels\train...:   0%|          | 0/195 [00:00<?, ?it/s]
# train: Scanning C:\Users\alexa\PycharmProjects\CondaYOLO\datasets\labels\train... 141 images, 0 backgrounds, 0 corrupt:  72%|#######2  | 141/195 [00:00<00:00, 1407.22it/s]
# train: Scanning C:\Users\alexa\PycharmProjects\CondaYOLO\datasets\labels\train... 195 images, 0 backgrounds, 0 corrupt: 100%|##########| 195/195 [00:00<00:00, 1563.37it/s]
#
# val: Scanning C:\Users\alexa\PycharmProjects\CondaYOLO\datasets\labels\valid...:   0%|          | 0/25 [00:00<?, ?it/s]
# ...
